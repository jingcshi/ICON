# %%
import os
import sys
import re
from typing import List, Union, Tuple, Dict, Callable, Any
sys.path.append(os.getcwd() + '/..')
sys.path.append(os.getcwd() + '/../..')
import torch
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from simcse import SimCSE
from transformers import BertForSequenceClassification, AutoModelForSeq2SeqLM, BertTokenizer, AutoTokenizer
from utils.taxo_utils import taxonomy
from utils import icon
from dataclasses import dataclass, fields, field

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
ret_model = SimCSE('/data2T/jingchuan/tuned/ret/entity_type_tuned_sota/',device=device)
gen_model = AutoModelForSeq2SeqLM.from_pretrained('/data2T/jingchuan/tuned/gen/flan-t5-sota/').to(device)
gen_tokenizer = AutoTokenizer.from_pretrained('/data2T/jingchuan/tuned/gen/flan-t5-sota/')
sub_model = BertForSequenceClassification.from_pretrained('/data2T/jingchuan/tuned/sub/bertsubs-sota/').to(device)
sub_tokenizer = BertTokenizer.from_pretrained('/data2T/jingchuan/tuned/sub/bertsubs-sota/',model_max_length=128)

# %%
taxo = taxonomy.from_json('./../data/raw/ebay_us.json')
df = pd.DataFrame(taxo.nodes(data='label'),columns=['ID','Label']).drop(0).reset_index(drop=True)

# %%
id_dict = {}
idx_dict = {}
for i,row in df.iterrows():
    idx_dict[i] = row['ID']
    id_dict[row['ID']] = i
def index_to_ID(x):
    return idx_dict[x]
def ID_to_index(id):
    return id_dict[id]

# %%
ret_model.build_index(list(df['Label']))
def RET_model(taxo:taxonomy,seed:Union[int,str],k=10):
    if isinstance(seed,int):
        seed = taxo.get_label(seed)
    topk = ret_model.search(seed,top_k=k)
    return [index_to_ID(i) for i,_,_ in topk]

# %%
def GEN_model(labels,prefix='summarize: '):
    corpus = prefix
    for l in labels:
        corpus += l + '; '
    corpus = corpus[:-2]
    inputs = gen_tokenizer(corpus,return_tensors='pt').to(device)['input_ids']
    outputs = gen_model.generate(inputs,max_length=64)[0]
    decoded = gen_tokenizer.decode(outputs.cpu().numpy(),skip_special_tokens=True)
    return decoded

# %%
def SUB_model(classpairs:Union[Tuple[str, str], Tuple[List[str], List[str]]],batch_size:int=256):
    sub, sup = classpairs
    if isinstance(sub,str):
        sub, sup = [sub], [sup]
    if len(sub) <= batch_size:
        inputs = sub_tokenizer(sub,sup,padding=True,return_tensors='pt').to(device)
        predictions = torch.softmax(sub_model(**inputs).logits.detach().cpu(),1)[:,1].numpy()
    else:
        head = (sub[:batch_size],sup[:batch_size])
        tail = (sub[batch_size:],sup[batch_size:])
        predictions = np.concatenate((sub_model(head),sub_model(tail)))
    return predictions

# %%
# kwargs = {'knn_model': knn_model,
#           'gen_model': gen_model,
#           'sub_model': sub_model,
#           'mode': 'manual',
#           'manual_inputs': ['plastic round tubes', 'pipe wrenches', 'mixed lots', 'mountain lions', 'opticals', 'port expansion cards', 'eagles', 'drawer slides', 'steel drums', 'softballs'],
#           'restrict_combinations': False,
#           'retrieve_size': 5,
#           'subs_threshold': 0.95,
#           'log': True}

# enriched_taxo, results = enrich.main(ontology, **kwargs)

# %%
kwargs = {'knn_model': RET_model,
        'gen_model': GEN_model,
        'sub_model': SUB_model,
        'mode': 'semiauto',
        'semiauto_seeds': [175781],
        'restrict_combinations': False,
        'retrieve_size': 10,
        'subs_threshold': 0.9,
        'log': True}

enriched_taxo = icon.main(taxo, **kwargs)
# Out:
# Loading:   0%|          | 0/20334 [00:00<?, ?it/s]
# Loaded taxonomy with 20334 nodes and 20339 edges. Commencing enrichment
# Semiauto mode:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Cycle 1: Seed 175781 (Men's Vintage T-Shirts)
# 		Retrieved 10 classes
# 			Men's Vintage T-Shirts
# 			Men's T-Shirts
# 			Men's Equestrian Shirts
# 			Women's Western Show Shirts
# 			Kids' Dance Tops & Shirts
# 			Adult Dance Tops & Shirts
# 			Vintage Sports Shirts
# 			Unisex Kids' Tops & T-Shirts
# 			Men's Western Show Shirts
# 			Boys' Tops, Shirts & T-Shirts
# 		Iteration 1.1: Combination (Men's Vintage T-Shirts, Men's T-Shirts)
# 		Generated common parent label: Men's Clothing
# 			Searching on a domain of 5 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Clothing (1059) and Men's Clothing
# 		Iteration 1.2: Combination (Men's Vintage T-Shirts, Men's Equestrian Shirts)
# 		Generated common parent label: Men's Equestrian Clothing
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Equestrian Clothing (183359) and Men's Equestrian Clothing
# 		Iteration 1.3: Combination (Men's Vintage T-Shirts, Women's Western Show Shirts)
# 		Generated common parent label: Women's Clothing
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Women's Clothing (15724) and Women's Clothing
# 		Iteration 1.4: Combination (Men's Vintage T-Shirts, Kids' Dance Tops & Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.5: Combination (Men's Vintage T-Shirts, Adult Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.6: Combination (Men's Vintage T-Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Vintage Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Vintage Clothing, Shoes & Accessories (175759) and Vintage Clothing, Shoes & Accessories
# 				The following class is declared as subclass of Vintage Clothing, Shoes & Accessories:
# 					Vintage Sports Shirts (64497)
# 		Iteration 1.7: Combination (Men's Vintage T-Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.8: Combination (Men's Vintage T-Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Men's Clothing
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Clothing (1059) and Men's Clothing
# 		Iteration 1.9: Combination (Men's Vintage T-Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.10: Combination (Men's T-Shirts, Men's Equestrian Shirts)
# 		Generated common parent label: Men's Equestrian Clothing
# 			Searching on a domain of 5 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Equestrian Clothing (183359) and Men's Equestrian Clothing
# 		Iteration 1.11: Combination (Men's T-Shirts, Women's Western Show Shirts)
# 		Generated common parent label: Women's Clothing
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Women's Clothing (15724) and Women's Clothing
# 		Iteration 1.12: Combination (Men's T-Shirts, Kids' Dance Tops & Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 9 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.13: Combination (Men's T-Shirts, Adult Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 9 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.14: Combination (Men's T-Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.15: Combination (Men's T-Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 9 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.16: Combination (Men's T-Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Men's Clothing
# 			Searching on a domain of 5 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Clothing (1059) and Men's Clothing
# 		Iteration 1.17: Combination (Men's T-Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 9 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.18: Combination (Men's Equestrian Shirts, Women's Western Show Shirts)
# 		Generated common parent label: Equestrian Clothing & Accessories
# 			Searching on a domain of 5 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Equestrian Clothing & Accessories (16240) and Equestrian Clothing & Accessories
# 		Iteration 1.19: Combination (Men's Equestrian Shirts, Kids' Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.20: Combination (Men's Equestrian Shirts, Adult Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.21: Combination (Men's Equestrian Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Sports & Equestrian Clothing
# 			Searching on a domain of 6 classes
# 			Search complete. Validated by NIL entity resolver
# 			Mapped to a known class by search
# 			Declared equivalence between Equestrian Clothing & Accessories (16240) and Sports & Equestrian Clothing
# 				The following class is declared as subclass of Equestrian Clothing & Accessories:
# 					Vintage Sports Shirts (64497)
# 		Iteration 1.22: Combination (Men's Equestrian Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Equestrian Clothing & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Equestrian Clothing & Accessories (16240) and Equestrian Clothing & Accessories
# 		Iteration 1.23: Combination (Men's Equestrian Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Men's Equestrian Clothing
# 			Searching on a domain of 3 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Equestrian Clothing (183359) and Men's Equestrian Clothing
# 		Iteration 1.24: Combination (Men's Equestrian Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Equestrian Clothing & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Equestrian Clothing & Accessories (16240) and Equestrian Clothing & Accessories
# 		Iteration 1.25: Combination (Women's Western Show Shirts, Kids' Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.26: Combination (Women's Western Show Shirts, Adult Dance Tops & Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.27: Combination (Women's Western Show Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Sports Clothing, Shoes & Accessories
# 			Searching on a domain of 4 classes
# 			Search complete. Validated by NIL entity resolver
# 			Rejected by search because no good placement can be found
# 		Iteration 1.28: Combination (Women's Western Show Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.29: Combination (Women's Western Show Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Jenkins & War Games
# 			Searching on a domain of 5 classes
# 			Search complete. Validated by NIL entity resolver
# 			Rejected by search because no good placement can be found
# 		Iteration 1.30: Combination (Women's Western Show Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.31: Combination (Kids' Dance Tops & Shirts, Adult Dance Tops & Shirts)
# 		Generated common parent label: Dance Specialty Clothing
# 			Searching on a domain of 5 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Dance Specialty Clothing (112425) and Dance Specialty Clothing
# 		Iteration 1.32: Combination (Kids' Dance Tops & Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Sports Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Validated by NIL entity resolver
# 			Accepted as a new class by search
# 			Created new class Sports Clothing, Shoes & Accessories with key 263474
# 				The following class is declared as superclass of Sports Clothing, Shoes & Accessories:
# 					Specialty Clothing, Shoes & Accessories (260033)
# 				The following classes are declared as subclasses of Sports Clothing, Shoes & Accessories:
# 					Equestrian Clothing & Accessories (16240)
# 					Dance Specialty Clothing (112425)
# 		Iteration 1.33: Combination (Kids' Dance Tops & Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Kids' Clothing (Sizes 4 & Up)
# 			Searching on a domain of 10 classes
# 			Search complete. Validated by NIL entity resolver
# 			Accepted as a new class by search
# 			Created new class Kids' Clothing (Sizes 4 & Up) with key 263475
# 				The following class is declared as superclass of Kids' Clothing (Sizes 4 & Up):
# 					Kids' Clothing, Shoes & Accessories (171146)
# 				The following classes are declared as subclasses of Kids' Clothing (Sizes 4 & Up):
# 					Kids' Dancewear (152345)
# 					Unisex Kids' Clothing (Sizes 4 & Up) (155198)
# 		Iteration 1.34: Combination (Kids' Dance Tops & Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.35: Combination (Kids' Dance Tops & Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Kids' Clothing (Sizes 4 & Up)
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Kids' Clothing (Sizes 4 & Up) (263475) and Kids' Clothing (Sizes 4 & Up)
# 				The following class is declared as subclass of Kids' Clothing (Sizes 4 & Up):
# 					Boys' Clothing (Sizes 4 & Up) (11452)
# 		Iteration 1.36: Combination (Adult Dance Tops & Shirts, Vintage Sports Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 6 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.37: Combination (Adult Dance Tops & Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.38: Combination (Adult Dance Tops & Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 7 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.39: Combination (Adult Dance Tops & Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Specialty Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Specialty Clothing, Shoes & Accessories (260033) and Specialty Clothing, Shoes & Accessories
# 		Iteration 1.40: Combination (Vintage Sports Shirts, Unisex Kids' Tops & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.41: Combination (Vintage Sports Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Sports & Souvenirs
# 			Searching on a domain of 4 classes
# 			Search complete. Validated by NIL entity resolver
# 			Rejected by search because no good placement can be found
# 		Iteration 1.42: Combination (Vintage Sports Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 11 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 		Iteration 1.43: Combination (Unisex Kids' Tops & T-Shirts, Men's Western Show Shirts)
# 		Generated common parent label: Men's Clothing
# 			Searching on a domain of 13 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Men's Clothing (1059) and Men's Clothing
# 		Iteration 1.44: Combination (Unisex Kids' Tops & T-Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Kids' Clothing (Sizes 4 & Up)
# 			Searching on a domain of 8 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Declared equivalence between Kids' Clothing (Sizes 4 & Up) (263475) and Kids' Clothing (Sizes 4 & Up)
# 		Iteration 1.45: Combination (Men's Western Show Shirts, Boys' Tops, Shirts & T-Shirts)
# 		Generated common parent label: Clothing, Shoes & Accessories
# 			Searching on a domain of 13 classes
# 			Search complete. Mapped to a known class by NIL entity resolver
# 			Warning: Search / NIL entity resolution suggests that Clothing, Shoes & Accessories is equivalent to multiple known classes
# 				Clothing, Shoes & Accessories with score 1.0000
# 				Specialty Clothing, Shoes & Accessories with score 0.9986
# 			For safety, only the highest ranked equivalence is preserved
# 			Declared equivalence between Clothing, Shoes & Accessories (11450) and Clothing, Shoes & Accessories
# 	Cycle complete. Added 2 new classes and 9 new direct subsumptions.
# Enrichment complete. Added 2 new classes and 9 new direct subsumptions. Begin post-processing with transitive reduction
# Return taxonomy with 20336 nodes and 20348 edges

# %%
class myclass:
    
    def __init__(self,
        ret_model=None,
        gen_model=None,
        sub_model=None,
        taxon_cache:Dict={},
        sub_score_cache:Dict={},
        mode:str='auto',
        max_outer_loop:int=None,
        semiauto_seeds:List[Union[int, str]]=[],
        manual_inputs:List[str]=[],
        inputs_bases:List[List[Union[int, str]]]=None,
        rand_seed=20230103,
        retrieve_size:int=10,
        restrict_combinations=True,
        ignore_label:List[str]=['','All categories','Root Concept','Thing','Allcats','Everything','root'],
        cached_subs_scores:Dict={},
        subgraph_crop:bool=True,
        subgraph_force:List[List[str]]=[['original']],
        subgraph_strict:bool=True,
        subs_threshold:float=0.5,
        search_tolerance:int=0,
        force_known_subsumptions:bool=False,
        force_prune_branches:bool=False,
        eqv_score_func:Callable[[Tuple[float, float]], float]=lambda x: x[0]*x[1],
        transitive_reduction:bool=True,
        log:Union[bool, int, List[str]]=False,
        ):
        saved_args = locals()
        print(saved_args)

# %%
@dataclass
class tree_config:
    
    def arglist(self):
        args = []
        for f in fields(self):
            if isinstance(getattr(self,f.name),tree_config):
                args += arglist(getattr(self,f.name))
            else:
                args.append(f.name)
        return args

@dataclass
class icon_models(tree_config):
    ret_model:Any
    gen_model:Any
    sub_model:Any

@dataclass
class icon_caches(tree_config):
    lexical_cache:Dict=field(default_factory=dict)
    sub_score_cache:Dict=field(default_factory=dict)

@dataclass
class icon_auto_config(tree_config):
    max_outer_loop:int=None

@dataclass
class icon_semiauto_config(tree_config):
    semiauto_seeds:List[Union[int, str]]=field(default_factory=list)

@dataclass
class icon_manual_config(tree_config):
    input_concepts:List[str]=field(default_factory=list)
    inputs_concept_bases:List[List[Union[int, str]]]=None

@dataclass
class icon_ret_config(tree_config):
    retrieve_size:int=10
    restrict_combinations:bool=True
    
@dataclass
class icon_gen_config(tree_config):
    ignore_label:List[str]=field(default_factory=list)
    filter_subset:bool=True

@dataclass
class icon_subgraph_config(tree_config):
    subgraph_crop:bool=True
    subgraph_force:List[List[str]]=field(default_factory=list)
    subgraph_strict:bool=True

@dataclass
class icon_search_config(tree_config):
    threshold:float=0.5
    tolerance:int=0
    force_base_subsumptions:bool=False
    force_prune:bool=False
    
@dataclass
class icon_sub_config(tree_config):
    subgraph:icon_subgraph_config=icon_subgraph_config()
    search:icon_search_config=icon_search_config()

@dataclass
class icon_update_config(tree_config):
    eqv_score_func:Callable[[Tuple[float, float]], float]=lambda x: x[0]*x[1]
    do_lexical_check:bool=True

    
@dataclass
class icon_config(tree_config):
    mode:str='auto'
    rand_seed:Any=114514
    auto_config:icon_auto_config=icon_auto_config()
    semiauto_config:icon_semiauto_config=icon_semiauto_config()
    manual_config:icon_manual_config=icon_manual_config()
    ret_config:icon_ret_config=icon_ret_config()
    gen_config:icon_gen_config=icon_gen_config()
    sub_config:icon_sub_config=icon_sub_config()
    update_config:icon_update_config=icon_update_config()
    transitive_reduction:bool=True
    log:Union[bool, int, List[str]]=False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb Cell 11 line 7
#      <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a>     eqv_score_func:Callable[[Tuple[float, float]], float]=lambda x: x[0]*x[1]
#      <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a>     do_lexical_check:bool=True
#      <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a> @dataclass
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> class icon_config(tree_config):
#      <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=72'>73</a>     mode:str='auto'
#      <a href='vscode-notebook-cell://ssh-remote%2Bkrrgpu1.cs.ox.ac.uk/home/jingchuan/Taxonomy_Completion-main/experiments/demo.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=73'>74</a>     rand_seed:Any=114514
#
# File ~/anaconda3/envs/ICON/lib/python3.8/dataclasses.py:1019, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen)
#    1016     return wrap
#    1018 # We're called as @dataclass without parens.
# -> 1019 return wrap(cls)
#
# File ~/anaconda3/envs/ICON/lib/python3.8/dataclasses.py:1011, in dataclass.<locals>.wrap(cls)
#    1010 def wrap(cls):
# -> 1011     return _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#
# File ~/anaconda3/envs/ICON/lib/python3.8/dataclasses.py:925, in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#     921     # Include InitVars and regular fields (so, not ClassVars).
#     922     flds = [f for f in fields.values()
#     923             if f._field_type in (_FIELD, _FIELD_INITVAR)]
#     924     _set_new_attribute(cls, '__init__',
# --> 925                        _init_fn(flds,
#     926                                 frozen,
#     927                                 has_post_init,
#     928                                 # The name to use for the "self"
#     929                                 # param in __init__.  Use "self"
#     930                                 # if possible.
#     931                                 '__dataclass_self__' if 'self' in fields
#     932                                         else 'self',
#     933                                 globals,
#     934                       ))
#     936 # Get the fields as a list, and include only real fields.  This is
#     937 # used in all of the following methods.
#     938 field_list = [f for f in fields.values() if f._field_type is _FIELD]
#
# File ~/anaconda3/envs/ICON/lib/python3.8/dataclasses.py:502, in _init_fn(fields, frozen, has_post_init, self_name, globals)
#     500             seen_default = True
#     501         elif seen_default:
# --> 502             raise TypeError(f'non-default argument {f.name!r} '
#     503                             'follows default argument')
#     505 locals = {f'_type_{f.name}': f.type for f in fields}
#     506 locals.update({
#     507     'MISSING': MISSING,
#     508     '_HAS_DEFAULT_FACTORY': _HAS_DEFAULT_FACTORY,
#     509 })
#
# TypeError: non-default argument 'auto_config' follows default argument
